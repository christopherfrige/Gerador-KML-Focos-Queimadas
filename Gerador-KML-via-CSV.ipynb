# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fastkml==0.12 in c:\users\queimadas\appdata\roaming\python\python39\site-packages (from -r requirements.txt (line 1)) (0.12)
# Requirement already satisfied: pandas==1.3.4 in c:\users\queimadas\appdata\roaming\python\python39\site-packages (from -r requirements.txt (line 2)) (1.3.4)
# Requirement already satisfied: Shapely==1.8.0 in c:\users\queimadas\appdata\roaming\python\python39\site-packages (from -r requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: lxml==4.6.4 in c:\users\queimadas\appdata\roaming\python\python39\site-packages (from -r requirements.txt (line 4)) (4.6.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: python-dateutil in c:\users\queimadas\appdata\roaming\python\python39\site-packages (from fastkml==0.12->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pygeoif<1.0 in c:\users\queimadas\appdata\roaming\python\python39\site-packages (from fastkml==0.12->-r requirements.txt (line 1)) (0.7)
# Requirement already satisfied: pytz>=2017.3 in c:\users\queimadas\appdata\roaming\python\python39\site-packages (from pandas==1.3.4->-r requirements.txt (line 2)) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\queimadas\appdata\roaming\python\python39\site-packages (from pandas==1.3.4->-r requirements.txt (line 2)) (1.21.3)
# Requirement already satisfied: six>=1.5 in c:\users\queimadas\appdata\roaming\python\python39\site-packages (from python-dateutil->fastkml==0.12->-r requirements.txt (line 1)) (1.16.0)

# %%
import pandas as pd
from fastkml import kml, styles
from shapely.geometry.polygon import Polygon, Point

# %%
file = r'csv\Focos_2021-11-01_2021-11-03.csv'

df = pd.read_csv(file)
df
# Out:
#                 datahora  satelite    pais estado               municipio  \
# 0    2021/11/01 04:10:00   NOAA-20  Brasil  GOIAS               SAO SIMAO
# 1    2021/11/01 16:41:00   NOAA-20  Brasil  GOIAS  SAO MIGUEL DO ARAGUAIA
# 2    2021/11/01 16:41:00   NOAA-20  Brasil  GOIAS                 FORMOSA
# 3    2021/11/01 16:41:00   NOAA-20  Brasil  GOIAS                 FORMOSA
# 4    2021/11/01 16:41:00   NOAA-20  Brasil  GOIAS                 FORMOSA
# ..                   ...       ...     ...    ...                     ...
# 145  2021/11/03 16:03:00   NOAA-20  Brasil  GOIAS                  CUMARI
# 146  2021/11/03 16:03:00   NOAA-20  Brasil  GOIAS                 CATALAO
# 147  2021/11/03 16:50:00  AQUA_M-T  Brasil  GOIAS                  CUMARI
# 148  2021/11/03 18:03:49   GOES-16  Brasil  GOIAS                 FORMOSA
# 149  2021/11/03 18:03:49   GOES-16  Brasil  GOIAS                 FORMOSA
#
#               bioma  diasemchuva  precipitacao  riscofogo  latitude  \
# 0    Mata Atlantica          0.0           0.1        0.1 -19.05603
# 1           Cerrado          1.0           5.9        0.3 -13.45615
# 2           Cerrado          1.0           0.8        0.8 -15.05474
# 3           Cerrado          1.0           0.8        0.6 -15.05527
# 4           Cerrado          1.0           0.8        0.9 -15.05806
# ..              ...          ...           ...        ...       ...
# 145         Cerrado          NaN           NaN        NaN -18.22014
# 146         Cerrado          NaN           NaN        NaN -18.06046
# 147         Cerrado          NaN           NaN        NaN -18.22040
# 148         Cerrado          NaN           NaN        NaN -15.41000
# 149         Cerrado          NaN           NaN        NaN -15.41000
#
#      longitude   frp
# 0    -50.59894   1.0
# 1    -50.52847   1.6
# 2    -47.51883  12.2
# 3    -47.52240  21.9
# 4    -47.51831  12.2
# ..         ...   ...
# 145  -48.20645  10.4
# 146  -47.38191   4.3
# 147  -48.20864   7.5
# 148  -47.29000   NaN
# 149  -47.31000   NaN
#
# [150 rows x 12 columns]

# %%
df_filtered = df.loc[:, ['latitude', 'longitude', 'datahora', 'satelite', 'estado', 'municipio']]
focos_data = df_filtered.values.tolist()
focos_data
# Out:
# [[-19.05603,
#   -50.59894,
#   '2021/11/01 04:10:00',
#   'NOAA-20',
#   'GOIAS',
#   'SAO SIMAO'],
#  [-13.45615,
#   -50.52847,
#   '2021/11/01 16:41:00',
#   'NOAA-20',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-15.05474, -47.51883, '2021/11/01 16:41:00', 'NOAA-20', 'GOIAS', 'FORMOSA'],
#  [-15.05527, -47.5224, '2021/11/01 16:41:00', 'NOAA-20', 'GOIAS', 'FORMOSA'],
#  [-15.05806, -47.51831, '2021/11/01 16:41:00', 'NOAA-20', 'GOIAS', 'FORMOSA'],
#  [-15.05859, -47.52187, '2021/11/01 16:41:00', 'NOAA-20', 'GOIAS', 'FORMOSA'],
#  [-16.1526, -52.3631, '2021/11/01 16:41:00', 'NOAA-20', 'GOIAS', 'BALIZA'],
#  [-16.19938, -52.51892, '2021/11/01 16:41:00', 'NOAA-20', 'GOIAS', 'BALIZA'],
#  [-16.77629, -47.91325, '2021/11/01 16:41:00', 'NOAA-20', 'GOIAS', 'LUZIANIA'],
#  [-17.30895,
#   -52.06934,
#   '2021/11/01 16:41:00',
#   'NOAA-20',
#   'GOIAS',
#   'CAIAPONIA'],
#  [-17.56561, -52.55533, '2021/11/01 16:41:00', 'NOAA-20', 'GOIAS', 'MINEIROS'],
#  [-17.80078, -47.62511, '2021/11/01 16:41:00', 'NOAA-20', 'GOIAS', 'CATALAO'],
#  [-13.2,
#   -50.15,
#   '2021/11/01 16:44:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.15,
#   '2021/11/01 16:54:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-15.05447, -47.52034, '2021/11/01 17:05:00', 'AQUA_M-T', 'GOIAS', 'FORMOSA'],
#  [-15.05608, -47.53081, '2021/11/01 17:05:00', 'AQUA_M-T', 'GOIAS', 'FORMOSA'],
#  [-13.20636,
#   -50.16308,
#   '2021/11/01 17:34:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.20755,
#   -50.15955,
#   '2021/11/01 17:34:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.20828,
#   -50.16334,
#   '2021/11/01 17:34:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2112,
#   -50.15834,
#   '2021/11/01 17:34:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.21198,
#   -50.1622,
#   '2021/11/01 17:34:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.21314,
#   -50.15854,
#   '2021/11/01 17:34:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.21388,
#   -50.16243,
#   '2021/11/01 17:34:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.21679,
#   -50.15734,
#   '2021/11/01 17:34:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.21758,
#   -50.16125,
#   '2021/11/01 17:34:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-15.30334,
#   -48.69262,
#   '2021/11/01 17:34:00',
#   'NPP-375',
#   'GOIAS',
#   'VILA PROPICIO'],
#  [-16.60664, -47.8801, '2021/11/01 17:34:00', 'NPP-375', 'GOIAS', 'LUZIANIA'],
#  [-16.60736, -47.87854, '2021/11/01 17:34:00', 'NPP-375', 'GOIAS', 'LUZIANIA'],
#  [-17.30374,
#   -52.06388,
#   '2021/11/01 17:34:00',
#   'NPP-375',
#   'GOIAS',
#   'CAIAPONIA'],
#  [-13.20561,
#   -50.15934,
#   '2021/11/01 17:34:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.15,
#   '2021/11/01 19:24:04',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.17,
#   '2021/11/01 19:24:04',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.15,
#   '2021/11/01 19:24:04',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.17,
#   '2021/11/01 19:24:04',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.15,
#   '2021/11/01 19:34:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.17,
#   '2021/11/01 19:34:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.15,
#   '2021/11/01 19:34:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.15,
#   '2021/11/01 19:44:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.17,
#   '2021/11/01 19:44:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.15,
#   '2021/11/01 19:44:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.15,
#   '2021/11/01 19:54:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.17,
#   '2021/11/01 19:54:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.15,
#   '2021/11/01 19:54:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.17,
#   '2021/11/01 19:54:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.15,
#   '2021/11/01 20:04:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.17,
#   '2021/11/01 20:04:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.15,
#   '2021/11/01 20:04:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.17,
#   '2021/11/01 20:04:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.15,
#   '2021/11/01 20:14:04',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.17,
#   '2021/11/01 20:14:04',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.15,
#   '2021/11/01 20:14:04',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.17,
#   '2021/11/01 20:14:04',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.15,
#   '2021/11/01 20:24:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.15,
#   '2021/11/01 20:24:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.17,
#   '2021/11/01 20:24:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.15,
#   '2021/11/01 20:34:04',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.15,
#   '2021/11/01 20:34:04',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.15,
#   '2021/11/01 20:44:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.15,
#   '2021/11/01 20:44:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2,
#   -50.15,
#   '2021/11/01 20:54:04',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.15,
#   '2021/11/01 20:54:04',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.22,
#   -50.15,
#   '2021/11/01 21:04:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.20615,
#   -50.16148,
#   '2021/11/02 03:49:00',
#   'NOAA-20',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.20642,
#   -50.16488,
#   '2021/11/02 03:49:00',
#   'NOAA-20',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.21233,
#   -50.16257,
#   '2021/11/02 03:49:00',
#   'NOAA-20',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2126,
#   -50.16596,
#   '2021/11/02 03:49:00',
#   'NOAA-20',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.21849,
#   -50.1637,
#   '2021/11/02 03:49:00',
#   'NOAA-20',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.21875,
#   -50.16718,
#   '2021/11/02 03:49:00',
#   'NOAA-20',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-15.07826,
#   -48.94951,
#   '2021/11/02 03:49:00',
#   'NOAA-20',
#   'GOIAS',
#   'BARRO ALTO'],
#  [-15.07841,
#   -48.94619,
#   '2021/11/02 03:49:00',
#   'NOAA-20',
#   'GOIAS',
#   'BARRO ALTO'],
#  [-15.07895,
#   -48.9461,
#   '2021/11/02 03:49:00',
#   'NOAA-20',
#   'GOIAS',
#   'BARRO ALTO'],
#  [-13.20841,
#   -50.15848,
#   '2021/11/02 04:42:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2112,
#   -50.16264,
#   '2021/11/02 04:42:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.21176,
#   -50.15902,
#   '2021/11/02 04:42:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.21511,
#   -50.15957,
#   '2021/11/02 04:42:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.2179,
#   -50.16374,
#   '2021/11/02 04:42:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.21846,
#   -50.16012,
#   '2021/11/02 04:42:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-18.46213,
#   -52.19604,
#   '2021/11/02 04:44:00',
#   'NPP-375',
#   'GOIAS',
#   'SERRANOPOLIS'],
#  [-18.45881,
#   -52.19547,
#   '2021/11/02 04:44:00',
#   'NPP-375',
#   'GOIAS',
#   'SERRANOPOLIS'],
#  [-14.71, -46.01, '2021/11/02 15:23:54', 'GOES-16', 'GOIAS', "SITIO D'ABADIA"],
#  [-14.69, -46.04, '2021/11/02 15:33:55', 'GOES-16', 'GOIAS', "SITIO D'ABADIA"],
#  [-14.71, -46.04, '2021/11/02 15:33:55', 'GOES-16', 'GOIAS', "SITIO D'ABADIA"],
#  [-16.15487, -52.42252, '2021/11/02 16:22:00', 'NOAA-20', 'GOIAS', 'BALIZA'],
#  [-14.55783,
#   -46.3378,
#   '2021/11/02 16:24:00',
#   'NOAA-20',
#   'GOIAS',
#   "SITIO D'ABADIA"],
#  [-15.02086, -47.40329, '2021/11/02 16:24:00', 'NOAA-20', 'GOIAS', 'FORMOSA'],
#  [-15.01779, -47.41105, '2021/11/02 16:24:00', 'NOAA-20', 'GOIAS', 'FORMOSA'],
#  [-13.28251,
#   -48.68256,
#   '2021/11/02 16:24:00',
#   'NOAA-20',
#   'GOIAS',
#   'MONTIVIDIU DO NORTE'],
#  [-14.07858,
#   -50.71905,
#   '2021/11/02 16:24:00',
#   'NOAA-20',
#   'GOIAS',
#   'NOVA CRIXAS'],
#  [-17.00044,
#   -53.05279,
#   '2021/11/02 17:13:00',
#   'NPP-375',
#   'GOIAS',
#   'SANTA RITA DO ARAGUAIA'],
#  [-15.93599, -47.063, '2021/11/02 17:13:00', 'NPP-375', 'GOIAS', 'CABECEIRAS'],
#  [-15.93563,
#   -47.06085,
#   '2021/11/02 17:13:00',
#   'NPP-375',
#   'GOIAS',
#   'CABECEIRAS'],
#  [-15.02177, -47.40672, '2021/11/02 17:13:00', 'NPP-375', 'GOIAS', 'FORMOSA'],
#  [-14.70289,
#   -47.80443,
#   '2021/11/02 17:13:00',
#   'NPP-375',
#   'GOIAS',
#   'AGUA FRIA DE GOIAS'],
#  [-14.66128,
#   -47.24164,
#   '2021/11/02 17:13:00',
#   'NPP-375',
#   'GOIAS',
#   "SAO JOAO D'ALIANCA"],
#  [-14.63359,
#   -47.02706,
#   '2021/11/02 17:13:00',
#   'NPP-375',
#   'GOIAS',
#   'FLORES DE GOIAS'],
#  [-18.28301,
#   -52.50135,
#   '2021/11/02 17:13:00',
#   'NPP-375',
#   'GOIAS',
#   'SERRANOPOLIS'],
#  [-18.27961,
#   -52.50198,
#   '2021/11/02 17:13:00',
#   'NPP-375',
#   'GOIAS',
#   'SERRANOPOLIS'],
#  [-16.90218,
#   -51.27154,
#   '2021/11/02 17:13:00',
#   'NPP-375',
#   'GOIAS',
#   'CAIAPONIA'],
#  [-16.90208, -51.2707, '2021/11/02 17:13:00', 'NPP-375', 'GOIAS', 'CAIAPONIA'],
#  [-19.13425,
#   -51.34497,
#   '2021/11/02 17:13:00',
#   'NPP-375',
#   'GOIAS',
#   'LAGOA SANTA'],
#  [-18.07854, -51.43081, '2021/11/02 17:13:00', 'NPP-375', 'GOIAS', 'JATAI'],
#  [-14.21085,
#   -50.72194,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'NOVA CRIXAS'],
#  [-13.8815,
#   -50.69826,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'NOVA CRIXAS'],
#  [-13.32205,
#   -50.40668,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.21454,
#   -46.82588,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'MONTE ALEGRE DE GOIAS'],
#  [-13.46694,
#   -49.80888,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'BONOPOLIS'],
#  [-13.32267,
#   -50.41024,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.29908,
#   -46.42118,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'DIVINOPOLIS DE GOIAS'],
#  [-14.02602,
#   -50.74222,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'NOVA CRIXAS'],
#  [-14.20605,
#   -50.71456,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'NOVA CRIXAS'],
#  [-14.20611,
#   -50.71763,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'NOVA CRIXAS'],
#  [-14.21082,
#   -50.71887,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'NOVA CRIXAS'],
#  [-14.20693,
#   -50.71956,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'NOVA CRIXAS'],
#  [-13.93656,
#   -50.62021,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'NOVA CRIXAS'],
#  [-13.88541,
#   -50.69756,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'NOVA CRIXAS'],
#  [-13.88271,
#   -50.70137,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'NOVA CRIXAS'],
#  [-13.88238,
#   -50.70329,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'NOVA CRIXAS'],
#  [-13.88185,
#   -50.69632,
#   '2021/11/02 17:15:00',
#   'NPP-375',
#   'GOIAS',
#   'NOVA CRIXAS'],
#  [-13.32,
#   -50.39,
#   '2021/11/02 18:34:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.32,
#   -50.39,
#   '2021/11/02 18:44:01',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.32,
#   -50.39,
#   '2021/11/02 18:54:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.32,
#   -50.39,
#   '2021/11/02 19:04:01',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.32,
#   -50.39,
#   '2021/11/02 19:14:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.32,
#   -50.39,
#   '2021/11/02 19:24:01',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.32,
#   -50.39,
#   '2021/11/02 19:34:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.32,
#   -50.39,
#   '2021/11/02 19:44:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.3,
#   -50.4,
#   '2021/11/02 19:54:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.32,
#   -50.42,
#   '2021/11/02 19:54:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.32,
#   -50.39,
#   '2021/11/02 19:54:02',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.32,
#   -50.39,
#   '2021/11/02 20:04:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.32,
#   -50.42,
#   '2021/11/02 20:04:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-13.3,
#   -50.4,
#   '2021/11/02 20:04:03',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-14.0, -50.82, '2021/11/02 20:13:59', 'GOES-16', 'GOIAS', 'NOVA CRIXAS'],
#  [-13.32,
#   -50.39,
#   '2021/11/02 20:14:01',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-14.0, -50.82, '2021/11/02 20:23:57', 'GOES-16', 'GOIAS', 'NOVA CRIXAS'],
#  [-13.32,
#   -50.39,
#   '2021/11/02 20:34:01',
#   'GOES-16',
#   'GOIAS',
#   'SAO MIGUEL DO ARAGUAIA'],
#  [-18.28263,
#   -52.50011,
#   '2021/11/03 04:23:00',
#   'NPP-375',
#   'GOIAS',
#   'SERRANOPOLIS'],
#  [-18.28356,
#   -52.49496,
#   '2021/11/03 04:23:00',
#   'NPP-375',
#   'GOIAS',
#   'SERRANOPOLIS'],
#  [-18.70591,
#   -50.91706,
#   '2021/11/03 04:23:00',
#   'NPP-375',
#   'GOIAS',
#   'CACHOEIRA ALTA'],
#  [-16.91128,
#   -51.56829,
#   '2021/11/03 04:23:00',
#   'NPP-375',
#   'GOIAS',
#   'CAIAPONIA'],
#  [-16.91508,
#   -51.56907,
#   '2021/11/03 04:23:00',
#   'NPP-375',
#   'GOIAS',
#   'CAIAPONIA'],
#  [-16.40345, -51.12978, '2021/11/03 04:23:00', 'NPP-375', 'GOIAS', 'IPORA'],
#  [-16.91603,
#   -51.57177,
#   '2021/11/03 05:14:00',
#   'NOAA-20',
#   'GOIAS',
#   'CAIAPONIA'],
#  [-18.22483, -48.20816, '2021/11/03 16:03:00', 'NOAA-20', 'GOIAS', 'CUMARI'],
#  [-18.22056, -48.21103, '2021/11/03 16:03:00', 'NOAA-20', 'GOIAS', 'CUMARI'],
#  [-18.22014, -48.20645, '2021/11/03 16:03:00', 'NOAA-20', 'GOIAS', 'CUMARI'],
#  [-18.06046, -47.38191, '2021/11/03 16:03:00', 'NOAA-20', 'GOIAS', 'CATALAO'],
#  [-18.2204, -48.20864, '2021/11/03 16:50:00', 'AQUA_M-T', 'GOIAS', 'CUMARI'],
#  [-15.41, -47.29, '2021/11/03 18:03:49', 'GOES-16', 'GOIAS', 'FORMOSA'],
#  [-15.41, -47.31, '2021/11/03 18:03:49', 'GOES-16', 'GOIAS', 'FORMOSA']]

# %%
class Arquivo:
    def __init__(self, kml_file):
        self.arquivo = kml_file
        self.logo_url = "http://queimadas.dgi.inpe.br/queimadas/portal-static/kml/images/logo.png"
        self.legenda_url = "http://queimadas.dgi.inpe.br/queimadas/portal-static/kml/images/legend.png"

    def iniciaArquivo(self):
        self.arquivo.write('<?xml version="1.0" encoding="UTF-8"?>')
    
    # Funções abaixo necessárias pois a biblioteca FastKML não possui a propriedade "ScreenOverlay"    
    def montarLogo(self):
        logo = f"""
    <ScreenOverlay>
      <name>Logo</name>
      <Icon>
        <href>{self.logo_url}</href>
      </Icon>
      <overlayXY x="1" y="1" xunits="fraction" yunits="fraction"/>
      <screenXY x="0.99" y="0.7" xunits="fraction" yunits="fraction"/>
      <size x="0" y="0" xunits="fraction" yunits="fraction"/>
    </ScreenOverlay>"""
        self.arquivo.writelines(logo)

    def montarLegenda(self):
        legenda = f"""
    <ScreenOverlay>
      <name>Legenda</name>
      <Icon>
        <href>{self.legenda_url}</href>
      </Icon>
      <overlayXY x="1" y="1" xunits="fraction" yunits="fraction"/>
      <screenXY x="0.99" y="0.55" xunits="fraction" yunits="fraction"/>
      <size x="0" y="0" xunits="fraction" yunits="fraction"/>
    </ScreenOverlay>"""
        self.arquivo.writelines(legenda)
        
    def finalizarArquivo(self):
        fim = """
  </Document>
</kml>
        """
        self.arquivo.writelines(fim)

# %%
k = kml.KML()
ns = '{http://www.opengis.net/kml/2.2}'
# Lista de satélites e cores correspondentes
SATELITES = ['AQUA_M-M', 'AQUA_M-T', 'GOES-16', 'METOP-B', 'METOP-C', 'MSG-03',
            'NOAA-18', 'NOAA-19', 'NOAA-20', 'NPP-375', 'TERRA_M-M', 'TERRA_M-T']
CORES = ('ff00ff00', 'ff00ff00', 'ffff1d00', 'ff14f0ff', 'ffcc3cf0', 'ffffff00',
            'ff0099ff', 'ff003399', 'ff6666ff', 'FFda01C1', 'ffccffcc', 'ffccffcc')

# Cria estilos e os adiciona numa lista
estilos = []
for i in range(len(SATELITES)):
    icon_style = styles.IconStyle(icon_href='http://maps.google.com/mapfiles/kml/shapes/placemark_square.png', scale=0.8, color=CORES[i])
    label_style = styles.LabelStyle(ns=ns, scale=0.6)
    lista_styles = styles.Style(styles = [icon_style, label_style], id=SATELITES[i])
    estilos.append(lista_styles)

# Cria o documento e adiciona a lista de estilos a ele
documento = kml.Document(ns=ns, name='Monitoramento de Queimadas Teste', description='Teste FastKML', styles=estilos)
k.append(documento)

# %%
# Cria a Folder principal
folder = kml.Folder(ns=ns, name='Focos por Satélite', description='Focos do último dia categorizado pelo satélite que o captou')
documento.append(folder)

# %%
subfolders_names = []
subfolders_objects = []
for foco in focos_data:
    # Para organizar os focos em pastas, e não recriá-las
    if not foco[3] in subfolders_names:
        subFolder = kml.Folder(ns=ns, name=foco[3])
        folder.append(subFolder)
        subfolders_names.append(foco[3])
        subfolders_objects.append(subFolder)
        
    descricao = f"""LAT = {foco[0]}
    LONG = {foco[1]}
    DATA = {foco[2]}
    SATÉLITE = {foco[3]}
    ESTADO = {foco[4]}
    MUNICÍPIO = {foco[5]}
    """

    ponto = kml.Placemark(ns=ns, name=foco[3], description=descricao, styleUrl=foco[3])
    ponto.geometry = Point([foco[1], foco[0]])
    subfolders_objects[subfolders_names.index(foco[3])].append(ponto)

# %%
with open(r'kml\kml_from_csv.kml', 'w+') as kml_file:
    arquivo = Arquivo(kml_file)
    arquivo.iniciaArquivo()
    # slicing de -22 para remover as propriedades </Document> e </kml>
    # para tornar possível a adição de Screens Overlays
    kml_file.writelines(k.to_string(prettyprint=True)[:-22])
    arquivo.montarLogo()
    arquivo.montarLegenda()
    arquivo.finalizarArquivo()
